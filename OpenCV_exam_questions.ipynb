# %% [markdown]
# <a href="https://colab.research.google.com/github/bloxton/OpenCV/blob/main/OpenCV_exam_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
#
arr1 = np.array([200, 250], dtype=np.uint8).reshape(-1, 1)
#print(arr1)
#print(arr1.shape)
#print(arr1.ndim)
#arr2 = np.array([200, 250], dtype=np.uint8).reshape(-1, 1)
#print(arr2)
#print(arr2.shape)
#print(arr2.ndim)
arr2 = np.array([40, 40], dtype=np.uint8).reshape(-1, 1)
add_numpy = arr1+arr2
add_cv2 = cv2.add(arr1, arr2)
#
print(arr1)
print(arr2)
print("Numpy add operation:" ,add_numpy)
print("OpenCV add operation:", add_cv2)
# Out:
# [[200]
#  [250]]
# [[40]
#  [40]]
# Numpy add operation: [[240]
#  [ 34]]
# OpenCV add operation: [[240]
#  [255]]
